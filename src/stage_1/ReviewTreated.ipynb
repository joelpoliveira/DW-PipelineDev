# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(color_codes=True)

# %%
OLD_PATH = "data/oldData/"
PROC_PATH = "data/processedData/"

# %%
dataset = pd.read_csv(f'{OLD_PATH}/review.csv')

# %%
dataset
# Out:
#        Company Model  Year      Reviewer         Date  \
# 0        acura   ilx  2013      mahowald   08/12/2012
# 1        acura   ilx  2013           VIP   07/26/2016
# 2        acura   ilx  2013     bybchucky   09/14/2013
# 3        acura   ilx  2013    bayareamom   01/26/2015
# 4        acura   ilx  2013   Kerry Olson   03/26/2016
# ...        ...   ...   ...           ...          ...
# 299040   volvo  xc70  2016    FirstVolvo   03/18/2017
# 299041   volvo  xc70  2016           Dhp   01/26/2016
# 299042   volvo  xc70  2016        Lisa B   05/03/2016
# 299043   volvo  xc70  2016         Milan   05/04/2019
# 299044   volvo  xc70  2016  Irving Gates   03/05/2019
#
#                                          Title  Rating  \
# 0              Getting 43 Mpg on daily commute       5
# 1                                New to me ILX       5
# 2                        Excellet Commuter Car       4
# 3                Peppy Hybrid that Turns Heads       4
# ...

# %%
dataset.head()
# Out:
#   Company Model  Year     Reviewer         Date  \
# 0   acura   ilx  2013     mahowald   08/12/2012
# 1   acura   ilx  2013          VIP   07/26/2016
# 2   acura   ilx  2013    bybchucky   09/14/2013
# 3   acura   ilx  2013   bayareamom   01/26/2015
# 4   acura   ilx  2013  Kerry Olson   03/26/2016
#
#                                    Title  Rating  \
# 0        Getting 43 Mpg on daily commute       5
# 1                          New to me ILX       5
# 2                  Excellet Commuter Car       4
# 3          Peppy Hybrid that Turns Heads       4
# 4  2013 Acura ILX Hybrid w/ Tech Package       5
#
#                                               Review
# 0  I love this car.\r\nGas mileage, suspension, a...
# 1  I purchased my 2013 ILX from the dealer used w...
# 2  I recently purchased a 2013 ILX with the Tech ...
# 3  We bought our ILX used and have been incredibl...
# 4  In April of 2015 we were in need of another ca...

# %%
dataset.tail()
# Out:
#        Company Model  Year      Reviewer         Date  \
# 299040   volvo  xc70  2016    FirstVolvo   03/18/2017
# 299041   volvo  xc70  2016           Dhp   01/26/2016
# 299042   volvo  xc70  2016        Lisa B   05/03/2016
# 299043   volvo  xc70  2016         Milan   05/04/2019
# 299044   volvo  xc70  2016  Irving Gates   03/05/2019
#
#                                          Title  Rating  \
# 299040                            Safety First       5
# 299041                          Best Volvo Yet       5
# 299042  I love this car!! I own a 2006 and 16!       5
# 299043                         Couldn't resist       5
# 299044        Bought the car out of the lease!       5
#
#                                                    Review
# 299040  Except for the fact that this unit must have s...
# 299041  Professional review was correct - crossover su...
# 299042  This car is comfy, rides like a dream, has gre...
# 299043  When I drove my sister's 2002 XC70 last year I...
# ...

# %%
dataset.describe(include='all')
# Out:
#        Company   Model           Year Reviewer         Date      Title  \
# count   299045  299045  299045.000000   298945       299028     299023
# unique      46     897            NaN   212359         7290     222701
# top     toyota  accord            NaN     Mike   10/22/2003  Great Car
# freq     29683    3650            NaN     1167          431       2019
# mean       NaN     NaN    2007.492247      NaN          NaN        NaN
# std        NaN     NaN       5.330847      NaN          NaN        NaN
# min        NaN     NaN    2000.000000      NaN          NaN        NaN
# 25%        NaN     NaN    2003.000000      NaN          NaN        NaN
# 50%        NaN     NaN    2006.000000      NaN          NaN        NaN
# 75%        NaN     NaN    2011.000000      NaN          NaN        NaN
# max        NaN     NaN    2020.000000      NaN          NaN        NaN
#
#                Rating  Review
# count   299045.000000  299041
# unique            NaN  296491
# ...

# %%
dataset.hist()
# Out:
# array([[<Axes: title={'center': 'Year'}>,
#         <Axes: title={'center': 'Rating'}>]], dtype=object)

# %%
sns.pairplot(dataset)

# %%
duplicate_rows_dataset = dataset[dataset.duplicated()]
print('number of duplicate rows: ', duplicate_rows_dataset.shape)
# Out:
# number of duplicate rows:  (310, 8)

# %%
dataset = dataset.drop_duplicates()
dataset.head()
# Out:
#   Company Model  Year     Reviewer         Date  \
# 0   acura   ilx  2013     mahowald   08/12/2012
# 1   acura   ilx  2013          VIP   07/26/2016
# 2   acura   ilx  2013    bybchucky   09/14/2013
# 3   acura   ilx  2013   bayareamom   01/26/2015
# 4   acura   ilx  2013  Kerry Olson   03/26/2016
#
#                                    Title  Rating  \
# 0        Getting 43 Mpg on daily commute       5
# 1                          New to me ILX       5
# 2                  Excellet Commuter Car       4
# 3          Peppy Hybrid that Turns Heads       4
# 4  2013 Acura ILX Hybrid w/ Tech Package       5
#
#                                               Review
# 0  I love this car.\r\nGas mileage, suspension, a...
# 1  I purchased my 2013 ILX from the dealer used w...
# 2  I recently purchased a 2013 ILX with the Tech ...
# 3  We bought our ILX used and have been incredibl...
# 4  In April of 2015 we were in need of another ca...

# %%
print(dataset.isna().sum())
# Out:
# Company       0
# Model         0
# Year          0
# Reviewer    100
# Date         17
# Title        22
# Rating        0
# Review        4
# dtype: int64

# %%
dataset.count()
# Out:
# Company     298735
# Model       298735
# Year        298735
# Reviewer    298635
# Date        298718
# Title       298713
# Rating      298735
# Review      298731
# dtype: int64

# %%
dataset = dataset.dropna()
dataset.count()
# Out:
# Company     298592
# Model       298592
# Year        298592
# Reviewer    298592
# Date        298592
# Title       298592
# Rating      298592
# Review      298592
# dtype: int64

# %%
dataset.to_csv(f"{PROC_PATH}/review.csv")
